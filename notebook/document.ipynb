# %%
from langchain_core.documents import Document

# %%
doc=Document(
    page_content="this is a text for RAG example",
    metadata={
        "source":"example.txt",
        "page":1,
        "Author":"sarath",
        "date_created":"13/01/2026"
    }
)
doc
# Out:
# Document(metadata={'source': 'example.txt', 'page': 1, 'Author': 'sarath', 'date_created': '13/01/2026'}, page_content='this is a text for RAG example')

# %%
#create a simple text file in data
import os 
os.makedirs("../data/text_files",exist_ok=True)

# %%
#path=os.path.join("../data/text_files","python_intro.txt")

# %%
sample_text={
    "../data/text_files/python_intro.txt":"""Python's Key Features

* Easy to Read and Learn: Python's simple, clean syntax reads almost like English, making it a great first language for beginners.
* Versatile and General-Purpose: You can use Python for almost anything:
    - Web Development (using frameworks like Django and Flask)
    - Data Science and Machine Learning (with libraries like Pandas, NumPy, and TensorFlow)
    - Automation and Scripting
    - Software Development
* Large Standard Library: It comes with a vast library of pre-written code (modules) for common tasks like working with data, networking, and more.
* Cross-Platform: Python code can run on Windows, macOS, and Linux without needing to be changed.
* Large Community: Python has a massive, active global community, which means it's easy to find help, tutorials, and libraries.
    """,
    "../data/text_files/Ml_intro.txt":"""What is Machine Learning?

Machine Learning (ML) is a subfield of artificial intelligence (AI). The core idea is simple: instead of writing explicit, step-by-step instructions
for a computer, you give it a large amount of data and let it "learn" patterns from that data.

The goal is to create a system (called a "model") that can make predictions, classifications, or decisions when it sees new, unseen data.

For example, instead of writing complex rules to identify spam email, you would "train" an ML model by showing it thousands of examples
of spam emails and thousands of examples of non-spam (ham) emails. The model learns the patterns associated with spam (like certain words,
sender types, etc.) and can then make an accurate prediction about new emails it receives.
    """
    
}

for file_path,content in sample_text.items():
    with open(file_path,'w',encoding="utf-8")as f:
        f.write(content)
print("sample text files created succesfully")
# Out:
# sample text files created succesfully

# %% [markdown]
# Text loader

# %%
#from langchain.document_loader import TextLoader
from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8" )
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content="Python's Key Features\n\n* Easy to Read and Learn: Python's simple, clean syntax reads almost like English, making it a great first language for beginners.\n* Versatile and General-Purpose: You can use Python for almost anything:\n    - Web Development (using frameworks like Django and Flask)\n    - Data Science and Machine Learning (with libraries like Pandas, NumPy, and TensorFlow)\n    - Automation and Scripting\n    - Software Development\n* Large Standard Library: It comes with a vast library of pre-written code (modules) for common tasks like working with data, networking, and more.\n* Cross-Platform: Python code can run on Windows, macOS, and Linux without needing to be changed.\n* Large Community: Python has a massive, active global community, which means it's easy to find help, tutorials, and libraries.\n    ")]

# %% [markdown]
# Directory loader

# %%
#Directory Loader 

from langchain_community.document_loaders import DirectoryLoader
